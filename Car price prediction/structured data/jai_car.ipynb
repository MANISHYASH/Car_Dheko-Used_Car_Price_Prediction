# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/jaipur_cars.xlsx')

# Function to flatten the nested dictionary in the first column
def flatten_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        flattened_data.append(data_dict)
    return pd.DataFrame(flattened_data)

# Flatten the first column
flattened_df = flatten_column(df['new_car_detail'])

# Display the first few rows of the flattened data
print(flattened_df.head())
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  centralVariantId           variantName  \
# 0        Hyundai i20       2015              1487         Asta 1.4 CRDi
# 1       Maruti Swift       2012             10403                   VXI
# 2     Maruti Celerio       2016              3982                VXI AT
# 3  Hyundai Grand i10       2017              5602  1.2 Kappa Magna BSIV
# 4     Maruti Wagon R       2016              4319               AMT VXI
#
#          price priceActual priceSaving priceFixedText  \
# 0  ₹ 5.10 Lakh                                   None
# 1  ₹ 3.81 Lakh                                   None
# 2  ₹ 3.20 Lakh                                   None
# 3  ₹ 4.20 Lakh                                   None
# 4  ₹ 3.50 Lakh                                   None
#
#                                         trendingText
# 0  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4  {'imgUrl': 'https://stimg.cardekho.com/used-ca...

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/jaipur_cars.xlsx')

# Function to flatten the nested dictionary in the second column
def flatten_overview_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant information
        flat_dict = {
            'Registration Year': None,
            'Insurance Validity': None,
            'Fuel Type': None,
            'Seats': None,
            'Kms Driven': None,
            'RTO': None,
            'Ownership': None,
            'Engine Displacement': None,
            'Transmission': None,
            'Year of Manufacture': None
        }
        for entry in data_dict['top']:
            flat_dict[entry['key']] = entry['value']
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the second column
flattened_overview_df = flatten_overview_column(df['new_car_overview'])

# Display the first few rows of the flattened data
print(flattened_overview_df.head())
# Out:
#   Registration Year     Insurance Validity Fuel Type    Seats    Kms Driven  \
# 0              2015  Third Party insurance    Diesel  5 Seats  1,20,000 Kms
# 1          Jan 2012            Third Party    Petrol  5 Seats    66,951 Kms
# 2              2016  Third Party insurance    Petrol  5 Seats    80,000 Kms
# 3          Apr 2017  Third Party insurance    Petrol  5 Seats    44,392 Kms
# 4              2016  Third Party insurance    Petrol  5 Seats    40,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year of Manufacture
# 0  RJ13  Second Owner             1396 cc       Manual               2015.0
# 1  RJ14   First Owner             1197 cc       Manual               2012.0
# 2  RJ14  Second Owner              998 cc    Automatic               2016.0
# 3  RJ14   First Owner             1197 cc       Manual               2017.0
# 4  RJ14   First Owner              998 cc    Automatic               2016.0

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/jaipur_cars.xlsx')

# Function to flatten the nested dictionary in the third column
def flatten_features_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant features
        flat_dict = {
            'Comfort & Convenience': [],
            'Interior': [],
            'Exterior': [],
            'Safety': [],
            'Entertainment & Communication': []
        }
        for feature_category in data_dict['data']:
            category_name = feature_category['heading']
            for feature in feature_category['list']:
                flat_dict[category_name].append(feature['value'])
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the third column
flattened_features_df = flatten_features_column(df['new_car_feature'])

# Display the first few rows of the flattened data
print(flattened_features_df.head())
# Out:
#                                Comfort & Convenience  \
# 0  [Power Steering, Power Windows Front, Power Wi...
# 1  [Power Steering, Power Windows Front, Power Wi...
# 2  [Power Steering, Power Windows Front, Power Wi...
# 3  [Power Steering, Power Windows Front, Power Wi...
# 4  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Adjustable Steering,...
# 1  [Air Conditioner, Heater, Adjustable Steering,...
# 2  [Air Conditioner, Heater, Digital Odometer, Ta...
# 3  [Air Conditioner, Heater, Digital Odometer, Ta...
# 4  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                             Exterior  \
# 0  [Adjustable Head Lights, Fog Lights Front, Pow...
# 1  [Adjustable Head Lights, Power Adjustable Exte...
# 2  [Adjustable Head Lights, Manually Adjustable E...
# 3  [Adjustable Head Lights, Power Adjustable Exte...
# 4  [Adjustable Head Lights, Fog Lights Front, Pow...
#
#                                               Safety  \
# 0  [Anti Lock Braking System, Centeral Locking, P...
# 1  [Anti Lock Braking System, Brake Assist, Cente...
# 2  [Centeral Locking, Child Safety Locks, Day Nig...
# 3  [Anti Lock Braking System, Centeral Locking, P...
# 4  [Centeral Locking, Power Door Locks, Child Saf...
#
#                        Entertainment & Communication
# 0  [Cd Player, Radio, Speakers Front, Speakers Re...
# 1  [Radio, Speakers Front, Speakers Rear, Usb Aux...
# 2                                                 []
# 3  [Speakers Front, Speakers Rear, Integrated2Din...
# 4  [Cd Player, Radio, Speakers Front, Speakers Re...

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/jaipur_cars.xlsx')

# Function to flatten the nested dictionary in the fourth column
def flatten_specs_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant specifications
        flat_dict = {
            'Mileage': None,
            'Engine': None,
            'Max Power': None,
            'Torque': None,
            'Wheel Size': None,
            'Seats': None
        }
        for spec_category in data_dict['top']:
            flat_dict[spec_category['key']] = spec_category['value']
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the fourth column
flattened_specs_df = flatten_specs_column(df['new_car_specs'])

# Display the first few rows of the flattened data
print(flattened_specs_df.head())
# Out:
#       Mileage   Engine Max Power    Torque Wheel Size Seats
# 0  22.54 kmpl  1396 CC  88.73bhp   219.7Nm         16     5
# 1  22.38 kmpl  1197 CC  88.50bhp     113Nm       None     5
# 2   23.1 kmpl   998 CC  67.04bhp      90Nm       None     5
# 3   18.9 kmpl  1197 CC  81.86bhp  113.75nm       None     5
# 4  20.51 kmpl   998 CC     67bhp      90Nm       None     5

# %%
import pandas as pd

# Concatenate DataFrames horizontally
merged_df = pd.concat([flattened_df, flattened_overview_df, flattened_features_df, flattened_specs_df], axis=1)

# Save to CSV
merged_df.to_csv('jai_car_merged_dataset.csv', index=False)

# %%
import pandas as pd


# Load the CSV data
df = pd.read_csv('D:/Car price prediction/New dataset/jai_car_merged_dataset.csv')

# Counting the number of elements in the list for specified columns
columns_to_count = ["Comfort & Convenience", "Interior", "Exterior", "Safety", "Entertainment & Communication"]
for column in columns_to_count:
    df[column] = df[column].apply(lambda x: len(eval(x)) if isinstance(x, str) else 0)

# Display the modified dataframe
print(df.head())
df.to_csv('jai_car_merged_dataset1.csv', index=False)
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...  Interior Exterior Safety  \
# 0        Hyundai i20       2015  ...        11       12     24
# 1       Maruti Swift       2012  ...         7        7     26
# 2     Maruti Celerio       2016  ...         9        5     13
# 3  Hyundai Grand i10       2017  ...         8        8     23
# 4     Maruti Wagon R       2016  ...        10       11     17
#
#   Entertainment & Communication     Mileage   Engine Max Power    Torque  \
# 0                             7  22.54 kmpl  1396 CC  88.73bhp   219.7Nm
# 1                             6  22.38 kmpl  1197 CC  88.50bhp     113Nm
# 2                             0   23.1 kmpl   998 CC  67.04bhp      90Nm
# 3                             6   18.9 kmpl  1197 CC  81.86bhp  113.75nm
# 4                             7  20.51 kmpl   998 CC     67bhp      90Nm
#
#   Wheel Size Seats.1
# 0         16     5.0
# 1        NaN     5.0
# 2        NaN     5.0
# 3        NaN     5.0
# 4        NaN     5.0
#
# [5 rows x 38 columns]
