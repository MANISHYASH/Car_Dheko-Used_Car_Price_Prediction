# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/delhi_cars.xlsx')

# Function to flatten the nested dictionary in the first column
def flatten_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        flattened_data.append(data_dict)
    return pd.DataFrame(flattened_data)

# Flatten the first column
flattened_df = flatten_column(df['new_car_detail'])

# Display the first few rows of the flattened data
print(flattened_df.head())
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia         Kia Seltos       2022              7121
# 1        Hyundai      Hyundai Creta       2016              1449
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020              6837
# 3         Maruti       Maruti Swift       2018             10403
# 4        Hyundai      Hyundai Creta       2017              5362
#
#           variantName        price priceActual priceSaving priceFixedText  \
# 0  GTX Plus Diesel AT    ₹ 19 Lakh                                   None
# 1          1.6 VTVT S  ₹ 7.62 Lakh                                   None
# 2                 200    ₹ 56 Lakh                                   None
# 3                 VXI  ₹ 5.23 Lakh                                   None
# 4     1.6 VTVT E Plus  ₹ 7.65 Lakh                                   None
#
#                                         trendingText
# 0  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4  {'imgUrl': 'https://stimg.cardekho.com/used-ca...

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/delhi_cars.xlsx')

# Function to flatten the nested dictionary in the second column
def flatten_overview_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant information
        flat_dict = {
            'Registration Year': None,
            'Insurance Validity': None,
            'Fuel Type': None,
            'Seats': None,
            'Kms Driven': None,
            'RTO': None,
            'Ownership': None,
            'Engine Displacement': None,
            'Transmission': None,
            'Year of Manufacture': None
        }
        for entry in data_dict['top']:
            flat_dict[entry['key']] = entry['value']
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the second column
flattened_overview_df = flatten_overview_column(df['new_car_overview'])

# Display the first few rows of the flattened data
print(flattened_overview_df.head())
# Out:
#   Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0              2022  Third Party insurance    Diesel  5 Seats  10,000 Kms
# 1          May 2016               Zero Dep    Petrol  5 Seats  57,437 Kms
# 2          Dec 2020          Comprehensive    Petrol  5 Seats   8,000 Kms
# 3          Jan 2019          Comprehensive    Petrol  5 Seats  28,151 Kms
# 4              2017  Third Party insurance    Petrol  5 Seats  60,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year of Manufacture
# 0  None   First Owner             1493 cc    Automatic                 2022
# 1  HR51  Second Owner             1591 cc       Manual                 2016
# 2  DL01   First Owner             1991 cc    Automatic                 2020
# 3  DL4C  Second Owner             1197 cc       Manual                 2018
# 4  DL8C   First Owner             1591 cc       Manual                 2017

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/delhi_cars.xlsx')

# Function to flatten the nested dictionary in the third column
def flatten_features_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant features
        flat_dict = {
            'Comfort & Convenience': [],
            'Interior': [],
            'Exterior': [],
            'Safety': [],
            'Entertainment & Communication': []
        }
        for feature_category in data_dict['data']:
            category_name = feature_category['heading']
            for feature in feature_category['list']:
                flat_dict[category_name].append(feature['value'])
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the third column
flattened_features_df = flatten_features_column(df['new_car_feature'])

# Display the first few rows of the flattened data
print(flattened_features_df.head())
# Out:
#                                Comfort & Convenience  \
# 0  [Power Steering, Power Windows Front, Power Wi...
# 1  [Power Steering, Power Windows Front, Power Wi...
# 2  [Power Steering, Power Windows Front, Power Wi...
# 3  [Power Steering, Power Windows Front, Power Wi...
# 4  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Adjustable Steering,...
# 1  [Air Conditioner, Heater, Adjustable Steering,...
# 2  [Air Conditioner, Heater, Adjustable Steering,...
# 3  [Air Conditioner, Heater, Adjustable Steering,...
# 4  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                             Exterior  \
# 0  [Adjustable Head Lights, Fog Lights Front, Pow...
# 1  [Adjustable Head Lights, Fog Lights Front, Pow...
# 2  [Adjustable Head Lights, Fog Lights Front, Pow...
# 3  [Adjustable Head Lights, Power Adjustable Exte...
# 4  [Adjustable Head Lights, Power Adjustable Exte...
#
#                                               Safety  \
# 0  [Anti Lock Braking System, Brake Assist, Cente...
# 1  [Anti Lock Braking System, Centeral Locking, P...
# 2  [Anti Lock Braking System, Brake Assist, Cente...
# 3  [Anti Lock Braking System, Brake Assist, Cente...
# 4  [Anti Lock Braking System, Centeral Locking, P...
#
#                        Entertainment & Communication
# 0  [Radio, Speakers Front, Speakers Rear, Integra...
# 1  [Cd Player, Radio, Speakers Front, Speakers Re...
# 2  [Radio, Speakers Front, Speakers Rear, Integra...
# 3  [Radio, Speakers Front, Speakers Rear, Usb Aux...
# 4  [Cd Player, Radio, Speakers Front, Speakers Re...

# %%
import pandas as pd
import ast

# Load the Excel file
df = pd.read_excel('D:/Car price prediction/DATASET/delhi_cars.xlsx')

# Function to flatten the nested dictionary in the fourth column
def flatten_specs_column(column):
    flattened_data = []
    for item in column:
        # Convert string representation of dictionary to actual dictionary
        data_dict = ast.literal_eval(item)
        # Extract relevant specifications
        flat_dict = {
            'Mileage': None,
            'Engine': None,
            'Max Power': None,
            'Torque': None,
            'Wheel Size': None,
            'Seats': None
        }
        for spec_category in data_dict['top']:
            flat_dict[spec_category['key']] = spec_category['value']
        flattened_data.append(flat_dict)
    return pd.DataFrame(flattened_data)

# Flatten the fourth column
flattened_specs_df = flatten_specs_column(df['new_car_specs'])

# Display the first few rows of the flattened data
print(flattened_specs_df.head())
# Out:
#       Mileage   Engine  Max Power Torque Wheel Size Seats
# 0     18 kmpl  1493 CC  113.43bhp  250Nm         17     5
# 1  15.29 kmpl  1591 CC   121.3bhp  151Nm       None     5
# 2  12.74 kmpl  1991 CC     197bhp  320nm         19     5
# 3  22.38 kmpl  1197 CC   88.50bhp  113Nm       None     5
# 4  15.29 kmpl  1591 CC   121.3bhp  151Nm       None     5

# %%
import pandas as pd

# Concatenate DataFrames horizontally
merged_df = pd.concat([flattened_df, flattened_overview_df, flattened_features_df, flattened_specs_df], axis=1)

# Save to CSV
merged_df.to_csv('del_car_merged_dataset.csv', index=False)

# %%
import pandas as pd


# Load the CSV data
df = pd.read_csv('D:/Car price prediction/New dataset/del_car_merged_dataset.csv')

# Counting the number of elements in the list for specified columns
columns_to_count = ["Comfort & Convenience", "Interior", "Exterior", "Safety", "Entertainment & Communication"]
for column in columns_to_count:
    df[column] = df[column].apply(lambda x: len(eval(x)) if isinstance(x, str) else 0)

# Display the modified dataframe
print(df.head())
df.to_csv('del_car_merged_dataset1.csv', index=False)
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  ...  Interior Exterior Safety  \
# 0            Kia         Kia Seltos       2022  ...        14       20     34
# 1        Hyundai      Hyundai Creta       2016  ...        10        9     23
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020  ...        14       16     42
# 3         Maruti       Maruti Swift       2018  ...         7        7     26
# 4        Hyundai      Hyundai Creta       2017  ...         9        8     23
#
#   Entertainment & Communication     Mileage   Engine  Max Power Torque  \
# 0                            11     18 kmpl  1493 CC  113.43bhp  250Nm
# 1                             8  15.29 kmpl  1591 CC   121.3bhp  151Nm
# 2                            12  12.74 kmpl  1991 CC     197bhp  320nm
# 3                             6  22.38 kmpl  1197 CC   88.50bhp  113Nm
# 4                             9  15.29 kmpl  1591 CC   121.3bhp  151Nm
#
#   Wheel Size Seats.1
# 0         17     5.0
# 1        NaN     5.0
# 2         19     5.0
# 3        NaN     5.0
# 4        NaN     5.0
#
# [5 rows x 38 columns]
